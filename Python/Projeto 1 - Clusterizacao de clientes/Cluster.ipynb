# %% [markdown]
# # 📊 Analise e Clusterização de clientes
#
# **Feito por:** Gabriel Paschoal Motta;<br>
# **Data:** Setembro 2025;<br>
# **Objetivo:** Analisar todas as informações extraidas dos clientes de uma empresa, descobrir os clientes principais e todas as caracteristicas do mesmos, desenvolver um modelo de Cluster para melhor visualização dos *clientes alvo*.
#
# ---

# %% [markdown]
# ### 🎯 __Meta analisando a base de dados__:
#
# - Descobrir qual o cliente alvo;
# - Qual a condição financeira do cliente alvo;
# - Descobrir mais sobre ele para com que se possa informar ao setor de marketing e planejar uma estratégia de acordo.
#
# Com base no que foi pedido, `vamos começar os processos`.
#
# ___

# %% [markdown]
# #### 💿 __1. Importando bibliotecas principais e os dados__
#
# Para o trabalho de analise requisitado sera, inicialmente, necessario algumas bibliotecas chave. Alem disso, tambem precisaremos importar a base de dados, um arquivo em .csv para nosso script Python.
#
# - Pandas: Para trabalhar como banco de dados, importar e exportar;
# - Numpy: Para trabalhar com funções matematicas (arrays e matrizes) e computação científica;
# - Matplotlib: Para fazer a plotagem dos gráficos;
# - Seaborn: Para criar visualizações de dados estatísticos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração de visualização
plt.style.use('seaborn-v0_8')
sns.set_palette('deep')

# Ignorar warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Com as bibliotecas importadas e configurações de visualização ajustadas, vamos importar e base de dados e imprimir alguns dados alem de analisarmos já algumas informações!

# %%
db = pd.read_csv(r"C:\Users\Gabriel\Portifolio\Projetos - Python\Projeto 1 - Clusterizacao de clientes\Dados\segmentation data.csv")

db.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
db.describe()
# Out:
#                  ID          Sex  Marital status          Age   Education  \
# count  2.000000e+03  2000.000000     2000.000000  2000.000000  2000.00000
# mean   1.000010e+08     0.457000        0.496500    35.909000     1.03800
# std    5.774946e+02     0.498272        0.500113    11.719402     0.59978
# min    1.000000e+08     0.000000        0.000000    18.000000     0.00000
# 25%    1.000005e+08     0.000000        0.000000    27.000000     1.00000
# 50%    1.000010e+08     0.000000        0.000000    33.000000     1.00000
# 75%    1.000015e+08     1.000000        1.000000    42.000000     1.00000
# max    1.000020e+08     1.000000        1.000000    76.000000     3.00000
#
#               Income   Occupation  Settlement size
# count    2000.000000  2000.000000      2000.000000
# mean   120954.419000     0.810500         0.739000
# std     38108.824679     0.638587         0.812533
# min     35832.000000     0.000000         0.000000
# ...

# %%
db.notna().sum()
# Out:
# ID                 2000
# Sex                2000
# Marital status     2000
# Age                2000
# Education          2000
# Income             2000
# Occupation         2000
# Settlement size    2000
# dtype: int64

# %% [markdown]
# __Resumo 1º tópico:__
#
# Bibliotecas importadas, base de dados importada, imprimido os primeiros itens, analisado as variaveis e os registros do DB(database).
# Tambem já sabemos algumas informações dos dados inseridos, categorias dos dados que preenchem cada coluna, algumas medias, maximos e minimos e afins.
# Por ultimo temos a informação de que, nesta base de dados, não existem valores nulos, assim dispensando tratamento referentes a isso. Alem disso tambem
# notamos que só temos variaveis numericas o que tambem facilita a analise, dispensando tratamento com one-hot-encoding.
# ___

# %% [markdown]
# #### 🧭 __2. Tratando e preparando dados__

# %% [markdown]
# Inicialmente, removeremos as colunas não uteis para a analise, aqui sera somente a coluna "ID".

# %%
db = db.drop('ID')
db.columns()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 db = db.drop('ID')
#       2 db.columns()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...
